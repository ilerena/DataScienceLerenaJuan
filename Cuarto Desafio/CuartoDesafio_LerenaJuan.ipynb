# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
drive.mount("mi_carpeta")
# Out:
# Mounted at mi_carpeta

# %%
# %cd mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science/Entregas DataScience/Cuarto Desafio
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science/Entregas DataScience/Cuarto Desafio

# %%
# %ls
# Out:
# BankChurners.csv  CuartoDesafio_LerenaJuan.ipynb

# %%
bank = pd.read_csv("BankChurners.csv", sep=",")

# %%
bank
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Antiquity_months  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                    39  ...                       1                      3
# 1                    44  ...                       1                      2
# 2                    36  ...                       1                      0
# 3                    34  ...                       4                      1
# 4                    21  ...                       1                      0
# ...                 ...  ...                     ...                    ...
# 10122                40  ...                       2                      3
# 10123                25  ...                       2                      3
# 10124                36  ...                       3                      4
# 10125                36  ...                       3                      3
# 10126                25  ...                       2                      4
#
#        Credit_Limit  debt  Open_To_Buy  Total_Trans_Amt  \
# 0           12691.0   777      11914.0             1144
# 1            8256.0   864       7392.0             1291
# 2            3418.0     0       3418.0             1887
# 3            3313.0  2517        796.0             1171
# 4            4716.0     0       4716.0              816
# ...             ...   ...          ...              ...
# 10122        4003.0  1851       2152.0            15476
# 10123        4277.0  2186       2091.0             8764
# 10124        5409.0     0       5409.0            10291
# 10125        5281.0     0       5281.0             8395
# 10126       10388.0  1961       8427.0            10294
#
#        Total_AmtTrans_Chng_Q4_Q1  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                          1.335              42                1.625
# 1                          1.541              33                3.714
# 2                          2.594              20                2.333
# 3                          1.405              20                2.333
# 4                          2.175              28                2.500
# ...                          ...             ...                  ...
# 10122                      0.703             117                0.857
# 10123                      0.804              69                0.683
# 10124                      0.819              60                0.818
# 10125                      0.535              62                0.722
# 10126                      0.703              61                0.649
#
#        Avg_Utilization_Ratio
# 0                      0.061
# 1                      0.105
# 2                      0.000
# 3                      0.760
# 4                      0.000
# ...                      ...
# 10122                  0.462
# 10123                  0.511
# 10124                  0.000
# 10125                  0.000
# 10126                  0.189
#
# [10127 rows x 21 columns]

# %% [markdown]
# El DataSet elegido es un base de datos de aproximadamente diez mil usuarios de una institución bancaria la cual he reunido una cantidad considerable de datos acerca de la situación de cada uno de ellos, tanto personal como en relación los paquetes que mantienen con el banco y su situación frente a ellos.
#
# Se puede observar que cada cliente cuenta con un número único de identificación, además tenemos información personal como ser la edad, el sexo, nivel de educación, estado marital, nivel de ingresos. Con respecto al paquete que tiene cada cliente contractualmente con el banco conocemos la cantidad de tarjetas adeherentes y las categorías de sus tarjetas.
#
# En lo que concierne directamente con la utilización de sus tarjetas, el banco otorga información de cada cliente que detalla:
#
# -	La antigüedad (en meses) que posee el cliente en la entidad
# -	El total de productos que posee con la entidad
# -	Los meses que estuve inactivo en el último año
# -	El límite de crédito otorgado por la entidad al cliente
# -	El monto total adeudado a la fecha
# -	El límite disponible para utilizar
# -	El total de operaciones realizadas
# -	El total en dinero de las operación realizadas
# -	El “Average credit utilization ratio” que es un índice basados es scores que indica la situación del cliente.
#
# Además debemos destacar como principal información la categorización con la contamos en “Existing Customer” y “Attrited Customer”. Esta atribución nos dice en qué situación se encuentra el cliente actualmente con respecto al banco al día de la fecha si sigue siendo un cliente activo o es un cliente en baja.
#
# A partir de esta categorización y con la información pertinente en conocimiento, es que se planteará una análisis del DataSet para evaluar si es posible establecer algún modelo que nos indique en base a alguna de las otras variables si es posible predecir la futura baja de un cliente y en base a eso donde se debe apuntar para mejor las condiciones de ese cliente para poder evitarla y mantenerlo como cliente de la entidad.

# %% [markdown]
# Lo que se buscará analizar en el dataset son aquellas distribuciones de las carácteristicas de los clientes clasificadas por el estado en el que se encuentra para poder así ver si alguna de ellas es inferencial en el status del cliente.

# %% [markdown]
# ## Distribución de la edad de todas los clientes, clasificado por estado.

# %%
sns.histplot(data=bank, x="Customer_Age", hue="Attrition_Flag", multiple="stack")
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Count'>

# %% [markdown]
# ## Dsitribución de la cantidad de meses que lleva inactivo un cliente, clasificado por estado.
# - Se observa distribución normal para ambos estados.

# %%
sns.histplot(data=bank, x="Months_Inactive_12_mon", hue="Attrition_Flag", multiple="stack", bins=6)
# Out:
# <Axes: xlabel='Months_Inactive_12_mon', ylabel='Count'>

# %% [markdown]
# # Relación de las cantidad de transacciones de cada cliente en relacion con tu limite de crédito.
# Observamos que a diferencia de los usarios activos donde las transacciones van hasta 139; para los inactivos el maximo de transacciones que tuvieron fue de 94 (ademas de tener la media muy por debajo)

# %%
sns.scatterplot(data=bank, x="Credit_Limit", y="Total_Trans_Ct", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Total_Trans_Ct'>

# %% [markdown]
# # Relacion de la deuda de cada clliente con respecto al Ratio otorgado por el banco.
#
# Podemos observar que, a pesar de haber una distribución homogénea por todo el panel, hay una zona muy especifica que es unicamente atribuible a los clientes que han dado de baja, que se conforma por aquellos que poseen un ratio mejor a 0,3 y una deuda menor a 500.

# %%
sns.scatterplot(data=bank, x="Avg_Utilization_Ratio", y="debt", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Avg_Utilization_Ratio', ylabel='debt'>

# %% [markdown]
# # Objetivo
#
# Establecer un modelo que nos permita predecir con el mayor porcentaje de efectividad posible, si un cliente dará de baja su paquete en el banco en el corto plazo, para poder ofrecer de manera preventiva descuentos, paquetes y promociones para evitar la baja.

# %% [markdown]
# # Contexto Comercial
#
# El Banco en cuestión se enfrente ante un continuo aumento en la baja de paquetes por parte de sus clientes. Quieren saber si efectivamente las bajas vienen aumento, y si es posible establecer una causa. Para esto, el banco ha proporcionado datos tanto personales como comerciales sobre sus clientes activos y los que han pedido la baja en el ultimo año.

# %% [markdown]
# # Problema Comercial
#
# Conociendo ciertos datos personales de los clientes como la edad, género, nivel educativo y estado marital, que son variables cualitativas y a priori no deberían tener tanta significancia, ¿podemos conocer si realmente esto es así y si en verdad alguna de estas es más importante de lo que se cree para nuestro modelo?
#
# El banco nos proporciona un índice (ratio) que calcúlan ellos para otorgar o negar ciertos paquetes o beneficios. ¿Podemos comprobar si realmente es confiable este ratio?
#
# Es el Nivel de Ingreso del cliente un consecuente para establecer una posible baja?
#
# Cambia algo en la decisión del cliente para mantenerse o darse de baja si le otorgo una mayor categoria de crédito o un mayor límite de gasto?
#
# Son los clientes que ya son baja los mas propensos a tener un límite menor ? y un mayor número de meses inactivo?

# %% [markdown]
# # Contexto Analítico
#
# El Gerente de operaciones del Banco nos proporciona un archivo .csv donde se encuentra el dataset con 10127 filas (cada fila es un cliente) y 21 columnas con toda la información que disponen de ellos.
# Se puede encontrar en el dataset información de tipo cuantitativa referida a el límite de crédito, cantidad de meses inactivo, cantidad de operaciones, nivel de gasto, entre otras; asi como también variables cualitativas, de índole personal como la edad, el sexo, nivel educativo y estado marital; y de índole comercial como ser el tipo de tarjeta que posee, el rango de su nivel de ingresos y su estado actual (activo o baja)

# %% [markdown]
# # Preguntas e hipótesis

# %% [markdown]
# -	¿Es posible predecir la futura baja de un cliente si posee una cantidad de transacciones en su tarjeta por debajo de cierto umbral?
# -	¿Tiene inferencia el nivel de ingresos del cliente en el mantenimiento de la cuenta más allá de su nivel de utilización?
# -	¿Es posible que el sexo del titular y/o la cantidad de tarjetas adherentes influyan a la hora de decidir darse de baja como cliente de la entidad?
# -	¿Es posible predecir una futura baja mediante el  “Average credit utilization ratio”?
# -	El límite de crédito otorgado al cliente y su porcentaje de utilización de ese límite es un indicador del posible estado de este?

# %% [markdown]
# ## Variables del dataset

# %%
bank.columns.tolist()
# Out:
# ['CLIENTNUM',
#  'Attrition_Flag',
#  'Customer_Age',
#  'Gender',
#  'Dependent_count',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category',
#  'Antiquity_months',
#  'Total_count_products',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon',
#  'Credit_Limit',
#  'debt',
#  'Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_AmtTrans_Chng_Q4_Q1',
#  'Total_Trans_Ct',
#  'Total_Ct_Chng_Q4_Q1',
#  'Avg_Utilization_Ratio']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # OTROS GRÁFICOS QUE REALIZE QUE NO ME GENERARON INFORMACION ÚTIL

# %%
sns.displot(data=bank, x="Income_Category", hue="Attrition_Flag", multiple="stack")

# %%
fig, ax = plt.subplots()
ax.hist(bank["Antiquity_months"])
# Out:
# (array([1402.,    0., 3561.,    0., 1535.,    0., 1790.,    0.,  727.,
#         1112.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(bank["Antiquity_months"])
# Out:
# (array([ 188.,  278.,  546., 1208., 1265., 3485., 1515.,  825.,  479.,
#          338.]),
#  array([13. , 17.3, 21.6, 25.9, 30.2, 34.5, 38.8, 43.1, 47.4, 51.7, 56. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(data=bank, x="Antiquity_months", hue="Attrition_Flag")

# %%
sns.scatterplot(data=bank, x="Antiquity_months", y="Dependent_count", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Antiquity_months', ylabel='Dependent_count'>

# %%
sns.scatterplot(data=bank, x="Antiquity_months", y="Customer_Age", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Antiquity_months', ylabel='Customer_Age'>

# %%
sns.scatterplot(data=bank, x="Credit_Limit", y="Open_To_Buy", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Open_To_Buy'>

# %%
sns.displot(data=bank, x="Customer_Age", hue="Gender", col="Gender")
