# %%
import pandas as pd

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from google.colab import drive

# %%
drive.mount("mi_carpeta")
# Out:
# Mounted at mi_carpeta

# %%
# %cd mi_carpeta
# Out:
# /content/mi_carpeta

# %%
# %cd Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science

# %%
# %ls
# Out:
#  cheat-sheet-pandas-seaborn.pdf  'Clase 7'/
# 'Clase 05'/                      'Clase 8'/
# 'Clase 2'/                        Clases.docx
# 'Clase 3'/                       'Data Science - Acceso directo.lnk'
# 'Clase  4'/                      'Entregas DataScience'/
# 'Clase 6'/                       'Material Extra'/

# %%
# %cd "Clase 8"
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science/Clase 8

# %%
# %ls
# Out:
#  BankChurners.csv
# 'Clase 08 - Guión de clase.docx'
#  Clase_08.ipynb
# 'Clase 8 - Visualizaciones y primeros pasos con Data Science (Parte II).pptx'
#  Clase8Yo.ipynb
#  Ejemplos_clase_DataVisualization_2.ipynb
#  Pruebas_segundo_desafio.ipynb
#  pune_1965_to_2002.csv
#  SeaBorn.docx

# %%
bank = pd.read_csv("BankChurners.csv")

# %%
bank
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ## Distribucion de la edad en el total de la muestra y por estado (activo y baja)

# %%
fig , ax = plt.subplots(figsize=(10,10),nrows=3)
ax[0].hist(bank["Customer_Age"], bins=47)
ax[1].hist(bank.loc[bank["Attrition_Flag"]=="Existing Customer"]["Customer_Age"], bins=47)
ax[2].hist(bank.loc[bank["Attrition_Flag"]=="Attrited Customer"]["Customer_Age"], bins=21)
ax[0].set_title("Total Muestra")
ax[1].set_title("Clientes Activos")
ax[2].set_title("Clientes Baja")
# Out:
# Text(0.5, 1.0, 'Clientes Baja')

# %% [markdown]
# # Cantidad de dependencias

# %%
conteo_categ = bank["Dependent_count"].value_counts().sort_index()

fig , ax = plt.subplots()
ax.bar(conteo_categ.index, conteo_categ.values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Distribucion sobre antiguedad

# %%
fig , ax = plt.subplots(figsize=(12,7), nrows=2)
ax[0].hist(bank.loc[bank["Attrition_Flag"]=="Existing Customer"]["Antiquity_months"], bins=15)
ax[0].set_title("Antiguedad (meses) de los activos")
ax[1].hist(bank.loc[bank["Attrition_Flag"]=="Attrited Customer"]["Antiquity_months"], bins=15)
ax[1].set_title("Antiguedad (meses) de los baja")
# Out:
# Text(0.5, 1.0, 'Antiguedad (meses) de los baja')

# %% [markdown]
# ## Relación de limite de tarjeta con cantidad de tansacciones:
# - No se visualiza realación alguna.

# %%
fig,ax=plt.subplots()
ax.scatter(bank["Total_Trans_Ct"], bank["Credit_Limit"])
ax.set_title("Relacion de limite de tarjeta con cantidad de transacciones")
# Out:
# Text(0.5, 1.0, 'Relacion de limite de tarjeta con cantidad de transacciones')

# %% [markdown]
# ## Relación del saldo para gastar con cantidad de tansacciones:
# - No se visualiza realación alguna.

# %%
fig,ax=plt.subplots()
ax.scatter(bank["Total_Trans_Ct"], bank["Open_To_Buy"])
ax.set_title("Relacion del saldo para gastar con cantidad de transacciones")
# Out:
# Text(0.5, 1.0, 'Relacion del saldo para gastar con cantidad de transacciones')

# %% [markdown]
# # SEABORN

# %%
bank.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# ## Distribución de los limites de crédito clasificados por género.

# %%
sns.displot(data=bank, x="Credit_Limit", hue="Gender", col="Gender")

# %%
sns.displot(data=bank, x="Credit_Limit", hue="Gender")

# %% [markdown]
# ## Relación de la edad de los clientes con su limite de crédito. Como se observan muchos valores para una misma edad se establece un intervalo de confianza.

# %%
sns.lineplot(data=bank, x="Customer_Age", y="Credit_Limit")
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# ## Relación de las cantidad de transacciones de cada cliente en relacion con tu limite de crédito.
# - Observamos que a diferencia de los usarios activos donde las transacciones van hasta 139; para los inactivos el maximo de transacciones que tuvieron fue de 94 (ademas de tener la media muy por debajo)

# %%
sns.scatterplot(data=bank, x="Credit_Limit", y="Total_Trans_Ct", hue="Attrition_Flag")
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Total_Trans_Ct'>

# %%
bank.loc[bank["Attrition_Flag"]=="Existing Customer"]["Total_Trans_Ct"].max()
# Out:
# 139

# %%
bank.loc[bank["Attrition_Flag"]=="Attrited Customer"]["Total_Trans_Ct"].max()
# Out:
# 94

# %% [markdown]
# ## Distribución de la edad de todas los clientes, clasificado por estado.
# - Ambos estados presentan una distribución normal.

# %%
sns.histplot(data=bank, x="Customer_Age", hue="Attrition_Flag", multiple="stack")
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Count'>

# %% [markdown]
# ## Dsitribución de la cantidad de meses que lleva inactivo un cliente, clasificado por estado.
# - Se observa distribución normal para ambos estados.

# %%
sns.histplot(data=bank, x="Months_Inactive_12_mon", hue="Attrition_Flag", multiple="stack", bins=6)
# Out:
# <Axes: xlabel='Months_Inactive_12_mon', ylabel='Count'>
