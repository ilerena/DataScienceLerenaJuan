# %%
from google.colab import drive

# %%
import pandas as pd

# %%
drive.mount("mi_carpeta")
# Out:
# Mounted at mi_carpeta

# %%
# %cd mi_carpeta
# Out:
# /content/mi_carpeta

# %%
# %ls
# Out:
# Escritorio/  IGNACIO/

# %%
# %cd Othercomputers
# Out:
# /content/mi_carpeta/Othercomputers

# %%
# %cd "Mi Portátil (1)"
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)

# %%
# %cd IGNACIO/CODERHOUSE/"Data Science"/"Entregas DataScience"/"Primera PreEntrega"
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science/Entregas DataScience/Primera PreEntrega

# %%
# %ls
# Out:
#  Coffe.csv                 PrimeraEntrega.ipynb
#  Data_AAPL_AMZN_MSFT.csv  'Walmart Data Analysis and Forcasting.csv'

# %%
pd.read_csv("Coffe.csv", sep=",")
# Out:
#      Unnamed: 0   ID Country of Origin  \
# 0             0    0          Colombia
# 1             1    1            Taiwan
# 2             2    2              Laos
# 3             3    3        Costa Rica
# 4             4    4          Colombia
# ..          ...  ...               ...
# 202         202  202            Brazil
# 203         203  203         Nicaragua
# 204         204  204              Laos
# 205         205  205       El Salvador
# 206         206  206            Brazil
#
#                                   Lot Number  \
# 0                                 CQU2022015
# 1    The 2022 Pacific Rim Coffee Summit,T037
# 2    The 2022 Pacific Rim Coffee Summit,LA01
# 3                                 CQU2022017
# 4                                 CQU2023002
# ..                                       ...
# 202                                   019/22
# 203                             017-053-0155
# 204                         105/3/VL7285-005
# ...

# %%
coffe_df = pd.read_csv("Coffe.csv", sep=",")

# %% [markdown]
# ## En esta variable "coffe_df" se guardo el DF con los datos sobre exportaciones de cafe diferentes empresas del mundo. Datos a analizar:
#    - Ranking de paises con mas exportaciones
#    - Compañias con mas exportaciones
#    - Variedades de Cafe mas significativas
#    - Metodos de proceso mas usados
#    - máximos, mínimos, promedios, medias y modas de:
#         - Acidez
#         - Cuerpo
#         - Balance
#         - uniformidad
#    - Colores mas exportados
#    - Vencimientos mas cortos y mas largos.

# %%
pd.read_csv("Data_AAPL_AMZN_MSFT.csv", delimiter=",")
# Out:
#             date     open     high      low    close     volume  Name
# 0     08/02/2013  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1     11/02/2013  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2     12/02/2013  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3     13/02/2013  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4     14/02/2013  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# ...          ...      ...      ...      ...      ...        ...   ...
# 3772  01/02/2018  94.7900  96.0700  93.5813  94.2600   47227882  MSFT
# 3773  02/02/2018  93.6400  93.9700  91.5000  91.7800   47867753  MSFT
# 3774  05/02/2018  90.5600  93.2400  88.0000  88.0000   51031465  MSFT
# 3775  06/02/2018  86.8900  91.4750  85.2500  91.3300   67998564  MSFT
# 3776  07/02/2018  90.4900  91.7700  89.2000  89.6100   41107592  MSFT
#
# [3777 rows x 7 columns]

# %%
stocks_df = pd.read_csv("Data_AAPL_AMZN_MSFT.csv", delimiter=",")

# %% [markdown]
# En esta variable "stocks_df" se guardo el DF con los datos sobre las cotizaciones de tres diferentes de las mas grandes empresas IT del mundo.
# En el se analizarán mínimos, máximos, Aperturas y cierres del precio por empresa.
# Asi como también, utilizando estos mismos indicadores pero segmentando por espacio temporal (Meses, trimestres, años)

# %%
pd.read_csv("Walmart Data Analysis and Forcasting.csv")
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05/02/2010    1643690.90             0        42.31       2.572
# 1         1  12/02/2010    1641957.44             1        38.51       2.548
# 2         1  19/02/2010    1611968.17             0        39.93       2.514
# 3         1  26/02/2010    1409727.59             0        46.63       2.561
# 4         1  05/03/2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28/09/2012     713173.95             0        64.88       3.997
# 6431     45  05/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19/10/2012     718125.53             0        56.47       3.969
# 6434     45  26/10/2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
walmart_df = pd.read_csv("Walmart Data Analysis and Forcasting.csv")

# %% [markdown]
# En esta variable "walmart_df" se guardo el DF con los datos que se obtuvieron de las distintas sucursales de la empresa walmart con respecto a las ventas de estas. Con indicadores adicionales como ser si eran semanas laborales o de vacaciones, temperatura promedio del dia (para luego analizar si es influyente en el volumen de ventas), el precio del combustible de la ciudad donde pertenece la sucursal, el indice de precios al consumidor de esa ciudad y el indice de desempleo. Todas estas variables adicionales se utilizaran para ver si existe correlación alguna para luego descartar o concretar causalidad. Además de puede hacer un análisis completo por segmentación de cada una de ellas a gusto.
