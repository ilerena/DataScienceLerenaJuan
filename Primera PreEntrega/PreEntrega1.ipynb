# %%
from google.colab import drive

# %%
import pandas as pd

# %%
drive.mount("mi_carpeta")
# Out:
# Mounted at mi_carpeta

# %%
# %cd mi_carpeta
# Out:
# /content/mi_carpeta

# %%
# %ls
# Out:
# MyDrive/  Othercomputers/

# %%
# %cd Othercomputers
# Out:
# /content/mi_carpeta/Othercomputers

# %%
# %ls
# Out:
# 'Mi Portátil (1)'/

# %%
# %cd "Mi Portátil (1)"
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)

# %%
# %ls
# Out:
# IGNACIO/

# %%
# %cd IGNACIO/CODERHOUSE/"Data Science"/"Entregas DataScience"/"Primera PreEntrega"
# Out:
# /content/mi_carpeta/Othercomputers/Mi Portátil (1)/IGNACIO/CODERHOUSE/Data Science/Entregas DataScience/Primera PreEntrega

# %%
# %ls
# Out:
# admissions_releases.csv  airbnb.csv  Coffe.csv  PrimeraEntrega.ipynb

# %%
coffe_DF = pd.read_csv("Coffe.csv", sep=",")

# %% [markdown]
# ## En esta variable "coffe_df" se guardo el DF con los datos sobre exportaciones de cafe diferentes empresas del mundo. Datos a analizar:
#    - Ranking de paises con mas exportaciones
#    - Compañias con mas exportaciones
#    - Variedades de Cafe mas significativas
#    - Metodos de proceso mas usados
#    - máximos, mínimos, promedios, medias y modas de:
#         - Acidez
#         - Cuerpo
#         - Balance
#         - uniformidad
#    - Colores mas exportados
#    - Vencimientos mas cortos y mas largos.

# %%
coffe_DF
# Out:
#      Unnamed: 0   ID Country of Origin  \
# 0             0    0          Colombia
# 1             1    1            Taiwan
# 2             2    2              Laos
# 3             3    3        Costa Rica
# 4             4    4          Colombia
# ..          ...  ...               ...
# 202         202  202            Brazil
# 203         203  203         Nicaragua
# 204         204  204              Laos
# 205         205  205       El Salvador
# 206         206  206            Brazil
#
#                                   Lot Number  \
# 0                                 CQU2022015
# 1    The 2022 Pacific Rim Coffee Summit,T037
# 2    The 2022 Pacific Rim Coffee Summit,LA01
# 3                                 CQU2022017
# 4                                 CQU2023002
# ..                                       ...
# 202                                   019/22
# 203                             017-053-0155
# 204                         105/3/VL7285-005
# ...

# %%
prision_DF = pd.read_csv("admissions_releases.csv", sep=",")

# %% [markdown]
# ## En esta variable "prision_df" se guardo el DF con los datos sobre el origen de las personas que fueron encarceladas y liberadas a travez de los meses en diferentes estados de EEUU.
# ## Los indicadores a analizar serán promedios, máximos, mínimos, medias sobre los datos. Además se podrán segmentar estos indicadores por estado, y por distintos segmentos de fecha (trimestres, años, historial completo)

# %%
prision_DF
# Out:
#             date  admissions_total  admissions_white  admissions_black  \
# 0     2015-02-01              1583               600               193
# 1     2015-03-01              1580               615               189
# 2     2015-04-01              1779               706               235
# 3     2015-05-01              1821               730               260
# 4     2015-06-01              1689               704               215
# ...          ...               ...               ...               ...
# 1909  2022-03-01              3475               812               746
# 1910  2022-04-01              3126               770               701
# 1911  2022-05-01              3221               851               699
# 1912  2022-06-01              2624               611               576
# 1913  2022-07-01              2192               604               479
#
#       admissions_hispanic  admissions_amerind  admissions_asian  \
# ...

# %%
airbnb_DF = pd.read_csv("airbnb.csv", sep=",")

# %% [markdown]
# ## En esta variable "airbnb_DF" se guardo el DF con los datos sobre reserbas de AirBnb en la ciudad de buenos aires durante un período seleccionado.
# ## Las variables a analizar serian los barrios mas solicitados; máximos, mínimos y promedios de precios; cantidad de noches promedio de alquiler; promedio anual de ocupación, promedio de hosts por persona; entre otras.

# %%
airbnb_DF
# Out:
#       id_reserva  id_host        ciudad id_barrio         barrio   latitud  \
# 0          48678  HBA0100  Buenos Aires     BA028       Recoleta -34.58722
# 1         100930  HBA0225  Buenos Aires     BA003      Balvanera -34.60475
# 2          98934  HBA0219  Buenos Aires     BA028       Recoleta -34.58990
# 3          77942  HBA0158  Buenos Aires     BA031  San Cristobal -34.62364
# 4         197288  HBA0390  Buenos Aires     BA028       Recoleta -34.59243
# ...          ...      ...           ...       ...            ...       ...
# 1673     2018802  HBA2321  Buenos Aires     BA017      Monserrat -34.61181
# 1674     2069443  HBA0401  Buenos Aires     BA021        Palermo -34.58179
# 1675     2536100  HBA0815  Buenos Aires     BA033      San Telmo -34.61738
# 1676     2593652  HBA2582  Buenos Aires     BA021        Palermo -34.58888
# 1677     2776496  HBA2887  Buenos Aires     BA029         Retiro -34.59561
#
# ...
